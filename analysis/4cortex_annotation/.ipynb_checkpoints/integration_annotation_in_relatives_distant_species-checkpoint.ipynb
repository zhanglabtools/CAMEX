# %% [markdown]
# # CAMEX could achieve more accurate integration and annotation performance in both relatives and distant species
#
#
# This tutorial demonstrates that CAMEX could achieve more accurate integration and annotation performance in both relatives and distant species.
#
# Here, we use collected scRNA-seq data from four species: adult human visual cortex, frontal cortex, and cerebellum, mouse neocortex, as well as lizard and turtle pallium. Processed h5ad files can be downloaded from https://drive.google.com/drive/folders/1rwdjEvWFEFw82a0x2JzMi2jXICbUc5eb?usp=sharing

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
import time
import torch
import shutil
import warnings
import argparse
import importlib
import scanpy as sc

import pandas as pd
import numpy as mp

from CAMEX.base import Dataset
from CAMEX.trainer import Trainer

# %%
from params import PARAMS

# %%
t1 = time.time()

# %% [markdown]
# ## make log dir

# %%
time_start = time.strftime("%Y-%m-%d-%H-%M-%S")
log_path = f'./log/{time_start}/'
for k, v in PARAMS.items():
    v['time_start'] = time_start
    v['log_path'] = log_path
print(log_path)
# Out:
# ./log/2024-04-12-18-17-41/

# %%
os.makedirs(log_path, exist_ok=True)
shutil.copy('params.py', log_path + 'params_current.py')
print(f'time: {time_start}')
# Out:
# time: 2024-04-12-18-17-41

# %% [markdown]
# ## preprocess scRNA_seq data to construct a heterogeneous graph of cells and genes

# %%
#  —————————————————————————————————— 1 preprocess
print('start preprocess')
dataset = Dataset(**PARAMS['preprocess'])
# torch.save(dataset, log_path + 'dataset_preprocessed.pt')
# dataset = torch.load(f'{args.path}/log/2023-06-06-09-02-45/dataset_preprocessed.pt')
adata_CAMEX = dataset.adata_whole
dgl_data = dataset.dgl_data
# Out:
# start preprocess
#                                 raw-brain-human-Lake: reference  raw-brain-mouse-Chen: query  raw-brain-lizard-Tosches: query  raw-brain-turtle-Tosches: query
# excitatory neuron                                       14747.0                        906.0                           1910.0                           7151.0
# inhibitory neuron                                        6808.0                       1392.0                            242.0                           1490.0
# oligodendrocyte                                          4369.0                       3724.0                            551.0                            155.0
# cerebellar granule cell                                  3298.0                          NaN                              NaN                              NaN
# astrocyte                                                2524.0                       1757.0                            520.0                           6514.0
# oligodendrocyte precursor cell                           1358.0                       1792.0                            398.0                           1862.0
# Purkinje cell                                            1001.0                          NaN                              NaN                              NaN
# microglial cell                                           756.0                        724.0                            278.0                            589.0
# endothelial cell                                          219.0                       1197.0                              NaN                              NaN
# brain pericyte                                            209.0                          NaN                              NaN                            114.0
# ependymal cell                                              NaN                        413.0                              NaN                              NaN
# macrophage                                                  NaN                        167.0                              NaN                              NaN
# neural progenitor cell                                      NaN                          NaN                            133.0                            717.0

# %%
print('start train')
trainer = Trainer(adata_CAMEX, dgl_data, **PARAMS['train'])
# Out:
# start train

# %% [markdown]
# ## integration

# %%
trainer.integration()
# Out:
# --------------------------------------------- integration ---------------------------------------------
# epoch: 0, loss: 92.41205311998908
# epoch: 1, loss: 26.902813687736604
# epoch: 2, loss: 26.60553840354637
# epoch: 3, loss: 26.430049024982218
# epoch: 4, loss: 26.377021813098295
# epoch: 5, loss: 26.28268357265143
# epoch: 6, loss: 26.205284071557315
# epoch: 7, loss: 26.19109469284246
# epoch: 8, loss: 26.12942354178723
# epoch: 9, loss: 26.137421666839977

# %% [markdown]
# ## annotation

# %%
trainer.annotation()
# Out:
# --------------------------------------------- annotation ---------------------------------------------
# epoch: 0, loss: 87.08806246519089
# train_acc: {'raw-brain-human-Lakecell_acc': 0.9398}, test_acc: {'raw-brain-lizard-Toschescell_acc': 0.9286, 'raw-brain-mouse-Chencell_acc': 0.6216, 'raw-brain-turtle-Toschescell_acc': 0.9229}, train_ami:{'raw-brain-human-Lakecell_ami': 0.6704, 'raw-brain-lizard-Toschescell_ami': 0.7288, 'raw-brain-mouse-Chencell_ami': 0.6018, 'raw-brain-turtle-Toschescell_ami': 0.6682}, best_epoch: 0
# epoch: 1, loss: 55.37206554412842
# train_acc: {'raw-brain-human-Lakecell_acc': 0.9449}, test_acc: {'raw-brain-lizard-Toschescell_acc': 0.9246, 'raw-brain-mouse-Chencell_acc': 0.6729, 'raw-brain-turtle-Toschescell_acc': 0.9238}, train_ami:{'raw-brain-human-Lakecell_ami': 0.6697, 'raw-brain-lizard-Toschescell_ami': 0.7355, 'raw-brain-mouse-Chencell_ami': 0.6687, 'raw-brain-turtle-Toschescell_ami': 0.6693}, best_epoch: 1
# epoch: 2, loss: 53.6062576174736
# train_acc: {'raw-brain-human-Lakecell_acc': 0.9465}, test_acc: {'raw-brain-lizard-Toschescell_acc': 0.9204, 'raw-brain-mouse-Chencell_acc': 0.7386, 'raw-brain-turtle-Toschescell_acc': 0.9193}, train_ami:{'raw-brain-human-Lakecell_ami': 0.6673, 'raw-brain-lizard-Toschescell_ami': 0.7391, 'raw-brain-mouse-Chencell_ami': 0.713, 'raw-brain-turtle-Toschescell_ami': 0.6624}, best_epoch: 2
# epoch: 3, loss: 52.74205106496811
# train_acc: {'raw-brain-human-Lakecell_acc': 0.9481}, test_acc: {'raw-brain-lizard-Toschescell_acc': 0.9167, 'raw-brain-mouse-Chencell_acc': 0.7323, 'raw-brain-turtle-Toschescell_acc': 0.9159}, train_ami:{'raw-brain-human-Lakecell_ami': 0.6667, 'raw-brain-lizard-Toschescell_ami': 0.7327, 'raw-brain-mouse-Chencell_ami': 0.7001, 'raw-brain-turtle-Toschescell_ami': 0.6495}, best_epoch: 2
# epoch: 4, loss: 52.44211155176163
# train_acc: {'raw-brain-human-Lakecell_acc': 0.9451}, test_acc: {'raw-brain-lizard-Toschescell_acc': 0.9154, 'raw-brain-mouse-Chencell_acc': 0.7063, 'raw-brain-turtle-Toschescell_acc': 0.9108}, train_ami:{'raw-brain-human-Lakecell_ami': 0.6633, 'raw-brain-lizard-Toschescell_ami': 0.725, 'raw-brain-mouse-Chencell_ami': 0.6836, 'raw-brain-turtle-Toschescell_ami': 0.6422}, best_epoch: 2
# epoch: 5, loss: 52.28653633594513
# train_acc: {'raw-brain-human-Lakecell_acc': 0.9457}, test_acc: {'raw-brain-lizard-Toschescell_acc': 0.9149, 'raw-brain-mouse-Chencell_acc': 0.7008, 'raw-brain-turtle-Toschescell_acc': 0.9093}, train_ami:{'raw-brain-human-Lakecell_ami': 0.663, 'raw-brain-lizard-Toschescell_ami': 0.7279, 'raw-brain-mouse-Chencell_ami': 0.6785, 'raw-brain-turtle-Toschescell_ami': 0.6374}, best_epoch: 2
# epoch: 6, loss: 52.81116026639938
# train_acc: {'raw-brain-human-Lakecell_acc': 0.9487}, test_acc: {'raw-brain-lizard-Toschescell_acc': 0.9236, 'raw-brain-mouse-Chencell_acc': 0.7483, 'raw-brain-turtle-Toschescell_acc': 0.9213}, train_ami:{'raw-brain-human-Lakecell_ami': 0.6693, 'raw-brain-lizard-Toschescell_ami': 0.7449, 'raw-brain-mouse-Chencell_ami': 0.7218, 'raw-brain-turtle-Toschescell_ami': 0.6637}, best_epoch: 6
# epoch: 7, loss: 52.39621502161026
# train_acc: {'raw-brain-human-Lakecell_acc': 0.9461}, test_acc: {'raw-brain-lizard-Toschescell_acc': 0.9085, 'raw-brain-mouse-Chencell_acc': 0.707, 'raw-brain-turtle-Toschescell_acc': 0.9109}, train_ami:{'raw-brain-human-Lakecell_ami': 0.6637, 'raw-brain-lizard-Toschescell_ami': 0.7199, 'raw-brain-mouse-Chencell_ami': 0.6785, 'raw-brain-turtle-Toschescell_ami': 0.64}, best_epoch: 6
# epoch: 8, loss: 52.30125033855438
# train_acc: {'raw-brain-human-Lakecell_acc': 0.9452}, test_acc: {'raw-brain-lizard-Toschescell_acc': 0.9152, 'raw-brain-mouse-Chencell_acc': 0.6815, 'raw-brain-turtle-Toschescell_acc': 0.9075}, train_ami:{'raw-brain-human-Lakecell_ami': 0.6625, 'raw-brain-lizard-Toschescell_ami': 0.7246, 'raw-brain-mouse-Chencell_ami': 0.6683, 'raw-brain-turtle-Toschescell_ami': 0.6382}, best_epoch: 6
# epoch: 9, loss: 52.37915766239166
# train_acc: {'raw-brain-human-Lakecell_acc': 0.9487}, test_acc: {'raw-brain-lizard-Toschescell_acc': 0.9179, 'raw-brain-mouse-Chencell_acc': 0.7028, 'raw-brain-turtle-Toschescell_acc': 0.9153}, train_ami:{'raw-brain-human-Lakecell_ami': 0.6671, 'raw-brain-lizard-Toschescell_ami': 0.7288, 'raw-brain-mouse-Chencell_ami': 0.6817, 'raw-brain-turtle-Toschescell_ami': 0.6492}, best_epoch: 6

# %%
adata_CAMEX.write_h5ad(log_path + 'adata_CAMEX.h5ad', compression='gzip')

# %%
t2 = time.time()

# %%
print(f'time usage: {round(t2-t1)} seconds')
# Out:
# time usage: 1373 seconds

# %% [markdown]
# ## analysis

# %%
log_path
# Out:
# './log/2024-04-12-18-17-41/'

# %%
adata_CAMEX = sc.read_h5ad(log_path + 'adata_CAMEX.h5ad')
adata_CAMEX
# Out:
# AnnData object with n_obs × n_vars = 69985 × 2000
#     obs: 'cell_ontology_class', 'cell_ontology_id', 'cell_type1', 'dataset_name', 'donor', 'organ', 'organism', 'platform', 'region', 'tSNE1', 'tSNE2', 'batch', 'n_genes_by_counts', 'total_counts', 'cell_ontology_class_num', 'cell_class', 'cell_class_num'
#     var: 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection', 'mean', 'std'
#     uns: 'cell_type', 'data_order', 'dataset_description', 'dataset_type', 'hvg', 'log1p', 'neighbors', 'pca'
#     obsm: 'X_CAMEX_Annotation', 'X_CAMEX_Annotation_eval', 'X_CAMEX_Integration', 'X_pca', 'cell_train_class'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
adata_CAMEX.obs.head(5)
# Out:
#                             cell_ontology_class cell_ontology_id cell_type1 dataset_name donor  organ      organism    platform region      tSNE1      tSNE2                 batch  n_genes_by_counts  total_counts  cell_ontology_class_num               cell_class  cell_class_num
# index
# Gran_cbm1_TTAATCAGTCGC  cerebellar granule cell       CL:0001031       Gran    Lake_2018     1  Brain  Homo sapiens  snDrop-seq    cbm -26.725456 -30.189707  raw-brain-human-Lake                708        1090.0                        3  cerebellar granule cell               3
# Gran_cbm1_ACAACGACATCC  cerebellar granule cell       CL:0001031       Gran    Lake_2018     1  Brain  Homo sapiens  snDrop-seq    cbm -31.022097 -22.272980  raw-brain-human-Lake                646         915.0                        3  cerebellar granule cell               3
# Gran_cbm1_TATGTCTATATG  cerebellar granule cell       CL:0001031       Gran    Lake_2018     1  Brain  Homo sapiens  snDrop-seq    cbm -35.684959 -24.031462  raw-brain-human-Lake                701        1053.0                        3  cerebellar granule cell               3
# Gran_cbm1_TAATGGAAAATA  cerebellar granule cell       CL:0001031       Gran    Lake_2018     1  Brain  Homo sapiens  snDrop-seq    cbm -25.886816 -33.706535  raw-brain-human-Lake                715        1115.0                        3  cerebellar granule cell               3
# Gran_cbm1_CTGGACTACAGC  cerebellar granule cell       CL:0001031       Gran    Lake_2018     1  Brain  Homo sapiens  snDrop-seq    cbm -25.068712 -36.672504  raw-brain-human-Lake                651         960.0                        3  cerebellar granule cell               3

# %%
adata_CAMEX.obsm['X_CAMEX_Integration'].shape
# Out:
# (69985, 128)

# %%
sc.pp.neighbors(adata_CAMEX, use_rep='X_CAMEX_Integration')

# %%
sc.tl.umap(adata_CAMEX)

# %%
sc.pl.umap(adata_CAMEX, color=['batch', 'cell_ontology_class'], wspace=0.6)

# %%
sc.pp.neighbors(adata_CAMEX, use_rep='X_CAMEX_Annotation')

# %%
sc.tl.umap(adata_CAMEX)

# %%
sc.pl.umap(adata_CAMEX, color=['batch', 'cell_ontology_class'], wspace=0.6)
